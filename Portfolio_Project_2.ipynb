# %% [markdown]
# <a href="https://colab.research.google.com/github/anastasiia784/Data-Analyst-/blob/main/Portfolio_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Portfolio Project 2

# %% [markdown]
# **Goal:**
# Build a scalable Python-based tool to calculate statistical significance for multiple A/B test conversion metrics without hardcoding the number of metrics.
# The results should be ready for further visualization (Tableau / BI tools).

# %% [markdown]
# ### Import Required Libraries
# Import libraries for data processing and statistical testing.

# %%
# Required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.proportion import proportions_ztest


from google.colab import drive
drive.mount("/content/drive")

# %cd /content/drive/MyDrive/Mate_homework
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Mate_homework

# %% [markdown]
# ### Load the Dataset
# Load the dataset

# %%
# Load dataset
df = pd.read_csv("Portfolio_project_2.csv")

# Preview data structure
df.head()
# Out:
#          date               country   device continent         channel  test  \
# 0  2020-11-01         United States  desktop  Americas  Organic Search     2
# 1  2020-11-01         United States  desktop  Americas          Direct     2
# 2  2020-11-01                 India  desktop      Asia  Organic Search     2
# 3  2020-11-01                 Japan   mobile      Asia          Direct     2
# 4  2020-11-01  United Arab Emirates   mobile      Asia  Organic Search     2
#
#    test_group            event_name  value
# 0           2  sessions with orders     14
# 1           2  sessions with orders      8
# 2           2  sessions with orders      2
# 3           1  sessions with orders      1
# 4           1  sessions with orders      1

# %% [markdown]
# ### Inspect Available Event Names
# Confirm all available event names in the dataset.

# %%
df['event_name'].unique()
# Out:
# array(['sessions with orders', 'new account', 'session', 'scroll',
#        'select_promotion', 'session_start', 'user_engagement',
#        'first_visit', 'page_view', 'view_item', 'view_promotion',
#        'view_search_results', 'add_payment_info', 'add_shipping_info',
#        'begin_checkout', 'select_item', 'add_to_cart', 'click',
#        'view_item_list'], dtype=object)

# %% [markdown]
# ### Define Conversion Metrics
# Statically define required metrics using actual event names.

# %%
metrics = {
    'add_payment': 'add_payment_info',
    'add_shipping': 'add_shipping_info',
    'begin_checkout': 'begin_checkout',
    'new_accounts': 'new account'
}

SESSION_EVENT = 'session'
VALUE_COL = 'value'

# %% [markdown]
# ### Aggregate Event Counts
# Aggregate event counts for statistical calculations

# %%
pivot = (
    df
    .pivot_table(
        index=['test', 'test_group', 'event_name'],
        values=VALUE_COL,
        aggfunc='sum'
    )
    .reset_index()
)

pivot.head()
# Out:
#    test  test_group         event_name  value
# 0     1           1   add_payment_info   1988
# 1     1           1  add_shipping_info   3034
# 2     1           1        add_to_cart   1395
# 3     1           1     begin_checkout   3784
# 4     1           1              click    368

# %% [markdown]
# ### Create Z-test Function for Proportions
#
# Create a reusable function for A/B test significance testing.

# %%
def run_z_test(success_c, success_t, total_c, total_t):
    successes = np.array([success_c, success_t])
    totals = np.array([total_c, total_t])
    z_stat, p_value = proportions_ztest(successes, totals)
    return z_stat, p_value

# %% [markdown]
# ### Calculate Statistical Significance for All Metrics
#
# Loop through all metrics dynamically and calculate:
#
# conversion rates
#
# absolute and relative differences
#
# statistical significance

# %%
results = []

for test_number in pivot['test'].unique():

    for metric_name, event_name in metrics.items():

        # Control group = 1, Test group = 2
        numerator_control = pivot.query(
            "test == @test_number and test_group == 1 and event_name == @event_name"
        )[VALUE_COL].sum()

        numerator_test = pivot.query(
            "test == @test_number and test_group == 2 and event_name == @event_name"
        )[VALUE_COL].sum()

        denominator_control = pivot.query(
            "test == @test_number and test_group == 1 and event_name == @SESSION_EVENT"
        )[VALUE_COL].sum()

        denominator_test = pivot.query(
            "test == @test_number and test_group == 2 and event_name == @SESSION_EVENT"
        )[VALUE_COL].sum()

        # Conversion rates
        cr_control = numerator_control / denominator_control
        cr_test = numerator_test / denominator_test

        # Metric change (%)
        metric_change = (cr_test - cr_control) / cr_control * 100

        # Statistical test
        z_stat, p_value = run_z_test(
            numerator_control,
            numerator_test,
            denominator_control,
            denominator_test
        )

        results.append({
            'test': test_number,
            'metrics': f'{metric_name}/session',
            'numerator_event': event_name,
            'denominator_event': SESSION_EVENT,
            'numerator_control': numerator_control,
            'denominator_control': denominator_control,
            'conversion_rate_control': cr_control,
            'numerator_test': numerator_test,
            'denominator_test': denominator_test,
            'conversion_rate_test': cr_test,
            'metric_change_%': metric_change,
            'z_stat': z_stat,
            'p_value': p_value,
            'significant': p_value < 0.05
        })

# %% [markdown]
# ### Create Final Results Table

# %%
final_results_df = pd.DataFrame(results)
final_results_df
# Out:
#     test                 metrics    numerator_event denominator_event  \
# 0      1     add_payment/session   add_payment_info           session
# 1      1    add_shipping/session  add_shipping_info           session
# 2      1  begin_checkout/session     begin_checkout           session
# 3      1    new_accounts/session        new account           session
# 4      2     add_payment/session   add_payment_info           session
# 5      2    add_shipping/session  add_shipping_info           session
# 6      2  begin_checkout/session     begin_checkout           session
# 7      2    new_accounts/session        new account           session
# 8      3     add_payment/session   add_payment_info           session
# 9      3    add_shipping/session  add_shipping_info           session
# 10     3  begin_checkout/session     begin_checkout           session
# 11     3    new_accounts/session        new account           session
# 12     4     add_payment/session   add_payment_info           session
# 13     4    add_shipping/session  add_shipping_info           session
# 14     4  begin_checkout/session     begin_checkout           session
# 15     4    new_accounts/session        new account           session
#
#     numerator_control  denominator_control  conversion_rate_control  \
# 0                1988                45362                 0.043825
# 1                3034                45362                 0.066884
# 2                3784                45362                 0.083418
# 3                3823                45362                 0.084278
# 4                2344                50637                 0.046290
# 5                3480                50637                 0.068724
# 6                4262                50637                 0.084168
# 7                4165                50637                 0.082252
# 8                3623                70047                 0.051722
# 9                5298                70047                 0.075635
# 10               9532                70047                 0.136080
# 11               5856                70047                 0.083601
# 12               3731               105079                 0.035507
# 13               5128               105079                 0.048801
# 14              12555               105079                 0.119482
# 15               8984               105079                 0.085498
#
#     numerator_test  denominator_test  conversion_rate_test  metric_change_%  \
# 0             2229             45193              0.049322        12.542021
# 1             3221             45193              0.071272         6.560481
# 2             4021             45193              0.088974         6.660587
# 3             3681             45193              0.081451        -3.354299
# 4             2409             50244              0.047946         3.576911
# 5             3510             50244              0.069859         1.650995
# 6             4313             50244              0.085841         1.988164
# 7             4184             50244              0.083274         1.241934
# 8             3697             70439              0.052485         1.474630
# 9             5188             70439              0.073652        -2.621211
# 10            9264             70439              0.131518        -3.352445
# 11            5822             70439              0.082653        -1.133880
# 12            3601            105141              0.034249        -3.541234
# 13            4956            105141              0.047137        -3.411125
# 14           12267            105141              0.116672        -2.351523
# 15            8687            105141              0.082622        -3.362896
#
#       z_stat   p_value  significant
# 0  -3.924884  0.000087         True
# 1  -2.603571  0.009226         True
# 2  -2.978783  0.002894         True
# 3   1.542883  0.122859        False
# 4  -1.240994  0.214608        False
# 5  -0.709557  0.477979        False
# 6  -0.952898  0.340642        False
# 7  -0.588793  0.556000        False
# 8  -0.643172  0.520112        False
# 9   1.413727  0.157442        False
# 10  2.511389  0.012026         True
# 11  0.643489  0.519907        False
# 12  1.571106  0.116158        False
# 13  1.785795  0.074132        False
# 14  1.995998  0.045934         True
# 15  2.375457  0.017527         True

# %% [markdown]
# ### Save Results for BI Visualization

# %%
final_results_df.to_csv('ab_test_final_results.csv', index=False)

# %% [markdown]
# ### **Tableau Visualization**
#
#  https://public.tableau.com/views/ABTest_17651154233200/ABTest?:language=en-US&publish=yes&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link

# %% [markdown]
# Final results file
# https://drive.google.com/file/d/19CK-XlhtD-p3nok-bep4iG9NEuUntRvv/view?usp=sharing
